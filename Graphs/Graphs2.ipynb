# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
s1 = {'Jan':{'North':140,'South':160,'East':140,'West':180,'Central':110},
      'Feb':{'North':130,'South':200,'East':180,'West':150,'Central':160},
     'Mar':{'North':130,'South':130,'East':150,'West':200,'Central':130},
     'Apr':{'North':190,'South':200,'East':170,'West':120,'Central':110},
     'May':{'North':160,'South':200,'East':190,'West':180,'Central':120},
     'June':{'North':200,'South':170,'East':140,'West':140,'Central':170},
     'July':{'North':150,'South':110,'East':170,'West':110,'Central':130},
     'Aug':{'North':170,'South':160,'East':180,'West':130,'Central':200},
     'Sep':{'North':190,'South':130,'East':190,'West':150,'Central':150},
     'Oct':{'North':170,'South':140,'East':150,'West':190,'Central':160},
     'Nov':{'North':150,'South':170,'East':140,'West':110,'Central':170},
     'Dec':{'North':120,'South':200,'East':170,'West':140,'Central':130}}
d1 = pd.DataFrame(s1)
d1.index.name="Zones"
d1
# Out:
#          Jan  Feb  Mar  Apr  May  June  July  Aug  Sep  Oct  Nov  Dec
# Zones
# North    140  130  130  190  160   200   150  170  190  170  150  120
# South    160  200  130  200  200   170   110  160  130  140  170  200
# East     140  180  150  170  190   140   170  180  190  150  140  170
# West     180  150  200  120  180   140   110  130  150  190  110  140
# Central  110  160  130  110  120   170   130  200  150  160  170  130

# %%
g1=d1.plot(kind="bar")
plt.savefig('Graph1.jpg')

# %%
g1=d1.plot(kind="line")

# %%
plt.bar(d1.index,d1['Jan'])
# Out:
# <BarContainer object of 5 artists>

# %%
d1['Jan']=d1['Jan']/1000

# %%
d1
# Out:
#           Jan  Feb  Mar  Apr  May  June  July  Aug  Sep  Oct  Nov  Dec
# Zones
# North    0.14  130  130  190  160   200   150  170  190  170  150  120
# South    0.16  200  130  200  200   170   110  160  130  140  170  200
# East     0.14  180  150  170  190   140   170  180  190  150  140  170
# West     0.18  150  200  120  180   140   110  130  150  190  110  140
# Central  0.11  160  130  110  120   170   130  200  150  160  170  130

# %%
d1.plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Zones'>

# %%
plt.bar(d1.index,d1['Jan'])
plt.xlabel('Zones')
plt.ylabel('Jan')
plt.title("Rainfall")
# Out:
# Text(0.5, 1.0, 'Rainfall')

# %%
d1.plot(kind="hist",orientation='horizontal',histtype='step',cumulative=True)
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
a = np.array([78,72,69,81,63,67,75])
b = np.array([79,74,71,83,71,79,80,69])

# %%
plt.hist([a,b],orientation='horizontal',histtype='step',cumulative=True)
# Out:
# (array([[1., 1., 2., 3., 4., 4., 5., 6., 6., 7.],
#         [0., 0., 0., 1., 3., 4., 4., 4., 7., 8.]]),
#  array([63., 65., 67., 69., 71., 73., 75., 77., 79., 81., 83.]),
#  <a list of 2 list[Polygon] objects>)

# %%
c = np.array([13,71,66,82,68,37,15,52,34,13,53,66,25,17,53,13])
plt.hist([a,b,c],orientation='horizontal',histtype='step',cumulative=True)
# Out:
# (array([[ 0.,  0.,  0.,  0.,  0.,  0.,  0.,  2.,  5.,  7.],
#         [ 0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  4.,  8.],
#         [ 5.,  6.,  6.,  8.,  8., 11., 11., 14., 15., 16.]]),
#  array([13., 20., 27., 34., 41., 48., 55., 62., 69., 76., 83.]),
#  <a list of 3 list[Polygon] objects>)

# %%
plt.boxplot(c,showmeans=True,vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x12ed2599d00>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x12ed25a12e0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x12ed2599a30>],
#  'medians': [<matplotlib.lines.Line2D at 0x12ed25a1880>],
#  'fliers': [<matplotlib.lines.Line2D at 0x12ed25a1e20>],
#  'means': [<matplotlib.lines.Line2D at 0x12ed25a1b50>]}
